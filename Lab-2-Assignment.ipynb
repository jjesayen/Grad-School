# %% [markdown]
# # Lab 2 Optional Notebook Pre-Flow: KNN and Leakage-Safe Classification
#
# This notebook is an optional scratch workspace for the revised Lab 2 scope. The authoritative requirements are in `Lab-2-Assignment.md`.
#
# Final graded submissions must use:
# - `Lab-2-Assignment.py` for final executable code
# - `Lab-2-Report.md` for written explanations and reflection
# - `artifacts/` for plots, tables, metrics, or other outputs referenced by the report
#
# This notebook is not the final graded submission. Do not submit it unless your instructor explicitly asks for it.
#
# Lab 2 is scoped to Module 2 KNN work plus Module 1 data preparation and feature engineering, including target encoding for high-cardinality categorical features. The final submission requires leakage-safe preprocessing functions, a leakage audit, manual KNN mechanics, distance diagnostics, runtime-aware validation evidence, and result-specific interpretation. Later labs cover decision trees, ROC/PR curves, cross-validation, advanced tuning, feature importance, and learning-curve diagnostics.

# %% [markdown]
# ## Setup
# Run this cell first if you use the notebook for exploration.

# %%
from pathlib import Path

from category_encoders import TargetEncoder
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import OneHotEncoder, StandardScaler

RANDOM_STATE = 42
LAB_DIR = Path.cwd()
DATA_DIR = LAB_DIR / 'datasets'
ARTIFACT_DIR = LAB_DIR / 'artifacts'
FIGURE_DIR = ARTIFACT_DIR / 'figures'
TABLE_DIR = ARTIFACT_DIR / 'tables'

column_names = [
    'age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status',
    'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss',
    'hours-per-week', 'native-country', 'income',
]

FIGURE_DIR.mkdir(parents=True, exist_ok=True)
TABLE_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Part 1: Data Exploration and KNN Risk Notes

# %%
# Load adult.data and adult.test, standardize target labels, inspect data quality,
# and note data properties that may make KNN difficult.
# Keep final code in Lab-2-Assignment.py.

# %% [markdown]
# ## Part 2: Leakage-Safe Preprocessing and Feature Engineering

# %%
# Implement fit_preprocessing(train_df, y_train) and transform_preprocessing(df, preprocessing_state).
# Split before fitting transformations, one-hot encode low/moderate-cardinality categorical features,
# target encode high-cardinality categorical features from training data only, scale numeric features,
# compare one-hot vs target encoding for native-country, and create the leakage audit table.

# %% [markdown]
# ## Part 3: KNN Mechanics From Scratch

# %%
# Implement Euclidean distance and manual KNN on a small subset.
# Compare manual KNN predictions with scikit-learn KNeighborsClassifier on the same subset.

# %% [markdown]
# ## Part 4: KNN Experiments and Runtime-Aware Model Selection

# %%
# Train baseline scikit-learn KNN, run distance diagnostics before/after scaling,
# compare encoding strategies, run a runtime-aware manual validation loop over at least
# 10 k values and 2 distance settings, and evaluate the frozen final model once on adult.test.

# %% [markdown]
# ## Part 5: Evaluation, Artifacts, and Reflection

# %%
# Create validation/test confusion matrices, compile the required final artifact summary table,
# and draft notes for the final recommendation and workflow reflection.
